# %%
catboost_model = CatBoostRegressor(
    iterations=480,
    learning_rate=0.17,
    depth=6,
    loss_function='RMSE',
    verbose=0,                # Set to 100 to see logs every 100 iterations
    random_state=42
)
CatBoost MSE (test): 43828496226.72111
R² (train): 0.8997195494920129
R² (test): 0.8323676434660385
MAE (train): 85798.99636356015
MAE (test): 97486.6533901414
MAPE (train): 0.19523229383938723
MAPE (test): 0.20848412839966568
#####################################################################
iterations=550,
    learning_rate=0.3,
    depth=6,
    loss_function='MAE',
    verbose=0,                # Set to 100 to see logs every 100 iterations
    random_state=42
CatBoost MSE (test): 47869450199.55371
R² (train): 0.827712719163398
R² (test): 0.8169120678604531
MAE (train): 87436.94726578835
MAE (test): 96447.12153168206
MAPE (train): 0.17463117969566413
MAPE (test): 0.19429665109252411
##############################################################

# %%
xgb_regressor = XGBRegressor(
    objective='reg:squarederror', # For regression tasks, specify the objective
    n_estimators=180,             # Number of boosting rounds
    learning_rate=0.1,            # Step size shrinkage
    max_depth=4,                  # Maximum depth of a tree
    subsample=0.6,                # Subsample ratio of the training instance
    colsample_bytree=0.6,         # Subsample ratio of columns
    random_state=42,              # For reproducibility
    n_jobs=-1                     # Use all available CPU cores
)
XGBoost MSE: 52528712657.64994
Accuracy of test: 0.7990916265311266
Accuracy of train: 0.8376644338462151
#####################################################
xgb_regressor = XGBRegressor(
    objective='reg:squarederror', # For regression tasks, specify the objective
    n_estimators=200,             # Number of boosting rounds
    learning_rate=0.1,            # Step size shrinkage
    max_depth=4,                  # Maximum depth of a tree
    subsample=0.6,                # Subsample ratio of the training instance
    colsample_bytree=0.6,         # Subsample ratio of columns
    random_state=42,              # For reproducibility
    n_jobs=-1 ,
)
XGBoost MSE: 51914553210.05668
Accuracy of test: 0.8014406232878277
Accuracy of train: 0.8430483873897854
##############################################################################
xgb_regressor = XGBRegressor(
    objective='reg:squarederror', # For regression tasks, specify the objective
    n_estimators=250,             # Number of boosting rounds
    learning_rate=0.2,            # Step size shrinkage
    max_depth=6,                  # Maximum depth of a tree
    subsample=0.6,                # Subsample ratio of the training instance
    colsample_bytree=0.6,         # Subsample ratio of columns
    random_state=42,              # For reproducibility
    n_jobs=-1 ,
)
XGBoost MSE: 48267363051.93539
Accuracy of test: 0.8153901568919626
Accuracy of train: 0.9248347085353612
########################################################################################
xgb_regressor = XGBRegressor(
    objective='reg:squarederror', # For regression tasks, specify the objective
    n_estimators=200,             # Number of boosting rounds
    learning_rate=0.2,            # Step size shrinkage
    max_depth=5,                  # Maximum depth of a tree
    subsample=0.6,                # Subsample ratio of the training instance
    colsample_bytree=0.6,         # Subsample ratio of columns
    random_state=42,              # For reproducibility
    n_jobs=-1 ,
)
XGBoost MSE: 50175715940.29636
Accuracy of test: 0.8080912139823196
Accuracy of train: 0.8939372546361635
###############################################################################################
